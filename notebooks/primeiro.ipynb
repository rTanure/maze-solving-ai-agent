# %% [markdown]
# # Notebook para analisar os dados dos experimentos
#
# Esse diretório deve conter todos os notebooks que forem usados para a análise dos dados
#
# Nunca exclua um notebook de uma análise utilizada. Sempre crie um novo.
#
# utilize o diretório utils nesse em /notebooks para guardar funções utilitárias que podem ser usadas em mais de um notebook

# %%
from utils.notebook_util import notebook_util

notebook_util()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from notebooks.utils.notebook_util import notebook_util
#       2
#       3 notebook_util()
#
# ModuleNotFoundError: No module named 'notebooks'
